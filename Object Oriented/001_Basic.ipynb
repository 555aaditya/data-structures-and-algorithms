# %% [markdown]
# <h2 style="color:#C83F49"> Basics of Object Oriented Programming </h2>

# %% [markdown]
# <h4 style="color:#C1A1BD">1. Object</h4>
# <h4 style="color:#C1A1BD">2. Class</h4>
# <h4 style="color:#C1A1BD">3. Polymorphism</h4>
# <h4 style="color:#C1A1BD">4. Inheritance</h4>
# <h4 style="color:#C1A1BD">5. Abstraction</h4>
# <h4 style="color:#C1A1BD">6. Encapsulation</h4>
