# %% [markdown]
# <h2 style="color:#C83F49"> Double Underscore Methods </h2>

# %% [markdown]
# <h3 style="color:#C1A1BD">1. Initialization</h3>
#
# <h5 style="color:#4287f5"> __new__</h5>
# <h5 style="color:#4287f5"> __init__</h5>
# <h5 style="color:#4287f5"> __del__</h5>

# %%
# whenever a class is created __new__ and __init__ are called
# __new__ method will be called to create an object is created and __init__ method will be called to initialize the object
# While __init__ is responsible for initializing the newly created instance after it has been created, 
# __new__ is responsible for actually creating the instance
